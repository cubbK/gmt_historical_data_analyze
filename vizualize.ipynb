# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('output/gmt_links.csv', dtype={3: 'boolean', 4: 'boolean'})

# Drop rows where the 'Title' column is missing
df = df.dropna(subset=['Title'])

# Convert the 'Date' column to a datetime object
df['Date'] = pd.to_datetime(df['Date'], format='%B %d, %Y', errors='coerce')
pd.set_option('display.max_rows', None)
df = df.drop_duplicates()
df = df.sort_values(by='Date', ascending=True)
df = df.drop(columns=['Link'])


display(df.head())
# Out:
#                                 Title       Date  IsOutOfStock  IsP500
# 30                 1805: Sea of Glory 2020-04-06          True   False
# 379                 Risorgimento 1859 2020-04-06          True   False
# 378        Rise of the Roman Republic 2020-04-06          True   False
# 377                             Reds! 2020-04-06          True   False
# 376  Red Winter, Expanded 2nd Edition 2020-04-06          True    True

# %%
unique_titles_count = df["Title"].nunique()
print(f"Number of unique titles: {unique_titles_count}")

display(df["Title"].unique())
# Out:
# Number of unique titles: 505
# array(['1805: Sea of Glory', 'Risorgimento 1859',
#        'Rise of the Roman Republic', 'Reds!',
#        'Red Winter, Expanded 2nd Edition',
#        'Red Winter 2nd Edition Update Kit',
#        'Red Storm: Baltic Approaches', 'Red Storm', 'Red Flag Over Paris',
#        'Red Dust Rebellion', 'Red Badge of Courage',
#        'Rebel Raiders on the High Seas',
#        'Rebel Fury: Five Battles from the Campaigns of Chancellorsville and Chickamauga',
#        'River of Death', 'RAN', "Prussia's Glory II", "Prussia's Glory",
#        'Prime Minister', 'PQ-17',
#        'Plantagenet: Cousins’ War for England, 1459 - 1485',
#        'Plains Indian Wars', 'Phalanx',
#        'Pericles: The Peloponnesian Wars 460-400 BC',
#        'Pericles Mounted Map',
#        'People Power: Insurgency in the Philippines, 1983-1986',
#        'Pensacola, 1781', 'Pendragon: The Fall of Roman Britain',
#        'Pursuit of Glory, 2nd Edition', 'Pendragon Mounted Map',
#        'Roads to Moscow', 'Salamis',
#        'Space Empires Countersheets Reprint Edition',
#        'Space Empires 3" Box',
#        'Sovereign of Discord: A Fire in the Lake Expansion',
#        'Skies Above the Reich, 2nd Printing',
#        'Skies Above the Reich Mounted Maps', 'Skies Above Britain',
#        'Simple Great Battles of History - 2nd Edition',
#        'Simple GBoH Battle Manual', 'Silver Bayonet Mounted Map',
#        'Silver Bayonet - 25th Anniversary Edition',
#        'Sicily: FAB #2 - Mounted Mapboard', 'Sicily: FAB #2',
#        'Saints in Armor', 'Ship of the Line', 'Serpents of the Seas',
#        'Sekigahara, 5th Printing', 'Sekigahara Mounted Map',
#        'Seas of Thunder', 'Savannah', 'Saratoga 2006 Edition',
#        'Saratoga - Mounted Mapboard', 'Santa Fe Rails', 'Samurai',
#        "Salerno '43 Mounted Map, Supplemental 2nd Printing",
#        "Salerno '43 Mounted Map", "Salerno '43",
#        'Set of Dice for Commands & Colors: Medieval',
#        'Peloponnesian War, 2nd Printing', 'Pax Romana 2nd Edition',
#        'Pax Romana - Mounted Mapboard',
#        'No Retreat 2! The North African Front Mounted Maps',
#        'Nightfighter', 'Next War: Vietnam',
#        'Next War: Taiwan, 2nd Printing', 'Next War: Supplement #3',
#        'Next War: Supplement #2', 'Next War: Supplement #1',
#        'Next War: Poland, 2nd Edition', 'Next War: Korea, 2nd Edition',
#        'Next War: India-Pakistan', 'Newtown',
#        'Nevsky, Teutons and Rus in Collision, 1240-1242',
#        'No Retreat! 2: The North African Front, 3rd Edition',
#        'Navajo Wars, 2nd Printing', 'Mystery Wizard',
#        'Musket & Pike Dual Pack',
#        'Mr. President: The American Presidency, 2001-2020',
#        "Mr. Madison's War", 'Mons, 1914: The Mad Minute', 'Monmouth',
#        'Men of Iron Tri-Pack', 'Medieval Conspiracy',
#        'Labyrinth: The Forever War, 2015-?',
#        'Labyrinth: The Awakening 2010-?, 2nd Printing',
#        'Labyrinth 3" Game Box', 'MBT, 2nd Printing',
#        'Navajo Wars Mounted Map',
#        'No Retreat! 2: The North African Front, 3rd Edition Update Kit',
#        'No Retreat! 3: The French and Polish Fronts',
#        'No Retreat! 3rd Printing Card Deck', 'Pax Baltica',
#        'Paths of Glory, Deluxe Edition, 2nd Printing',
#        "Paths of Glory Player's Guide",
#        'Paths of Glory (Original) Mounted Map', 'Panzer, 3rd Printing',
#        'Panzer North Africa', 'Panzer Expansion #4: France 1940',
#        'Panzer Expansion #3: Drive to the Rhine - The 2nd Front, 2nd Printing',
#        'Panzer Expansion #2: The Final Forces on the Eastern Front, 2nd Printing',
#        'Panzer Expansion #1: The Shape of Battle - The Eastern Front, 2nd Printing',
#        'Pacific War: The Struggle Against Japan, 1941-1945',
#        'Pacific Typhoon', 'Operation Shoestring', 'Operation Mercury',
#        'Operation Dauntless', 'Onward Christian Soldiers (Ziplock)',
#        'Nothing Gained But Glory', "North Africa '41",
#        "Normandy '44, 3rd Printing", 'Norway, 1940: A PQ-17 Expansion',
#        'No Retreat!: The Russian Front Deluxe Ed., 3rd Printing',
#        'No Retreat! Mounted Map', 'No Retreat! Battles: 1942',
#        'No Retreat! 5: The Western Front, 1944-45',
#        'No Retreat! 4: The Italian Front',
#        'No Retreat! 4 The Italian Front Mounted Maps',
#        'Space Empires, 5th Printing', 'Manoeuvre: Distant Lands',
#        'Space Empires: All Good Things',
#        'Space Empires: Replicators, 2nd Printing', 'Victory in the West',
#        'Versailles 1919', 'US Civil War Mounted Maps',
#        'Urban Sprawl Mounted Map', 'Urban Sprawl',
#        'Unhappy King Charles!', 'Unhappy King Charles - Mounted Mapboard',
#        'Under the Southern Cross: Flying Colors Vol. IV',
#        'Under the Lily Banners',
#        'Unconditional Surrender! Western Campaigns',
#        'Unconditional Surrender! 3rd Printing',
#        'Unconditional Surrender - Mounted Mapboards (2), 2nd Printing',
#        'Vietnam: 1965-1975, GMT Edition', "Ukraine '43, 2nd Edition",
#        'Typhoon!', 'Twin Peaks',
#        'Twilight Struggle: Red Sea - Conflict in the Horn of Africa',
#        'Twilight Struggle Turn Zero and Promo Packs, 3rd Printing',
#        'Twilight Struggle Deluxe Mounted Mapboard',
#        'Twilight Struggle Deluxe Edition, 8th Printing',
#        'Twilight Struggle Deluxe Ed. Card Set',
#        'Twilight Struggle Counter Set',
#        'Triumph and Tragedy, 3rd Printing', 'Triumvir',
#        'Triumph and Tragedy, 2nd Edition Update Kit', 'Tyrant',
#        'Triumph & Glory',
#        'Vijayanagara: The Deccan Empires of Medieval India, 1290-1398',
#        "von Manstein's Backhand Blow", 'Zero!',
#        'WW2: Barbarossa to Berlin, 3rd Printing', 'Won by the Sword',
#        'Wolfpack', 'Wing Leader: Victories 1940-1942, 2nd Ed. Update Kit',
#        'Wing Leader: Supremacy 1943-1945, 2nd Edition',
#        'Wing Leader: Supremacy 2nd Edition Update Kit',
#        'Wing Leader: Victories 1940-1942, 2nd Ed.',
#        'Wing Leader: Origins 1936-42', 'Wing Leader: Legends 1937-1945',
#        'Virgin Queen, 2nd Printing', 'Wing Leader: Eagles',
#        'Wing Leader Supremacy Mounted Map', 'Winds of Plunder',
#        'Wilderness War Mounted Map', 'Wilderness War 2015 Edition',
#        'Wild Blue Yonder', 'Wellington',
#        'Welcome to Centerville Mounted Map', 'Welcome to Centerville',
#        "Waterloo: Napoleon's Last Battle",
#        "Washington's War, 3rd Printing", "Washington's War Mounted Map",
#        'War Galley', 'Wing Leader: Blitz', 'Time of Crisis, 2nd Printing',
#        'Time of Crisis Mounted Map', 'Time of Crisis 3" Game Box',
#        'The Burning Blue', 'The Bulge: FAB #1 - Mounted Mapboard',
#        'The Bulge: FAB #1',
#        'The British Way: Counterinsurgency at the End of Empire',
#        'The Bell of Treason: 1938 Munich Crisis in Czechoslovakia',
#        'The Battle of Rhode Island',
#        'The Battle for Normandy, Deluxe Edition',
#        'The Battle for Normandy Expansion', 'The Barracks Emperors',
#        'The Age of Iron and Rust: A Time of Crisis Expansion',
#        'Tanto Monta: The Rise of Ferdinand and Isabella',
#        'Tank Duel: Tank Pack #1', 'The Caucasus Campaign',
#        'Sword of Rome (+5th Player Expansion), 3rd Printing',
#        'Sun of York', 'Successors', 'Storm Over Asia',
#        'Storm Above the Reich', "Stalin's War - Mounted Mapboard",
#        "Stalin's War", "Stalingrad '42 Expansion", "Stalingrad '42",
#        'SPQR: Deluxe Edition, 2nd Printing', 'SPQR Dlx Scenario Pack',
#        'SpaceCorp: Ventures', 'SpaceCorp, 2nd Printing',
#        'Sweden Fights On', 'The Conquerors: Alexander the Great',
#        'The Dark Sands', 'The Dark Summer: Normandy 1944',
#        'Tigers in the Mist', 'Thunder in the East',
#        'Thunder Alley Track Set',
#        'Thunder Alley Crew Chief, 2nd Printing',
#        'Thunder Alley - New Track Pack', 'Thunder Alley',
#        'Three Days of Gettysburg',
#        'This Accursed Civil War, 2nd Printing', 'Thirty Years War',
#        'The Weimar Republic', 'The US Civil War, 2nd Printing',
#        'The US Civil War 2nd Edition Update Kit', 'The Supreme Commander',
#        'The Spanish Civil War', 'The Rise of the Luftwaffe',
#        'The Pure Land: Ōnin War in Muromachi Japan, 1465-1477',
#        'The Plum Island Horror', 'The Napoleonic Wars',
#        'The Last Hundred Yards, 2nd Printing',
#        'The Last Hundred Yards Volume 3: The Solomon Islands',
#        'The Last Hundred Yards Volume 2: Airborne Over Europe',
#        'The Last Hundred Yards Mission Pack #1',
#        "The Kaiser's Pirates Reprint Edition",
#        'The Hunters, 3rd Printing Update Kit', 'The Halls of Montezuma',
#        'The Great War in Europe: Deluxe Edition',
#        'The Dark Valley Deluxe Edition',
#        'Space Empires: Close Encounters, 3rd Printing',
#        'Manoeuvre, 3rd Printing', 'Space Empires Mounted Map', 'Mamluk',
#        'Caesar: Conquest of Gaul', 'Caesar In Alexandria',
#        'Caesar - The Civil Wars', 'C3i DiF Squadron Pack #2: Bombers',
#        'C3i DiF Squadron Pack #1: Fighters',
#        'C&C Napoleonics Dice and Stickers',
#        'C & C: Ancients Exp. Combo Pack #2 & 3, 2nd Printing',
#        'C & C: Ancients Exp. #6: The Spartan Army, 3rd Printing',
#        'C & C: Ancients Exp. #5: Epic Ancients II (2nd Printing)',
#        'C & C: Ancients Exp. #4: Imperial Rome',
#        'C & C: Ancients Exp. #1 Greece & Eastern Kingdoms (3rd Printing)',
#        'C & C Medieval Expansion 1: Crusades Mid-Eastern Battles 1',
#        'Caesar: Rome vs. Gaul', 'C & C Ancients Mounted Mapboard',
#        'Brandywine', 'Borodino', 'Border Reivers',
#        'Bomber Command Mounted Maps', 'Bomber Command',
#        'Blue vs. Gray: The Civil War Card Game (ziplock)',
#        'Blue Cross, White Ensign',
#        'Bloody April, 1917: Air War Over Arras, France', 'Blood & Roses',
#        'Blank Counter Sheet 9/16 Inch', 'Blank Counter Sheet 1 Inch',
#        'Blackbeard: The Golden Age of Piracy - 2nd Printing',
#        'Britain Stands Alone', 'Caratacus', 'Carthage', 'Case Yellow',
#        'Combat Commander: Europe Card Set (3 decks)',
#        'Combat Commander BP #6: Sea Lion, 2nd Printing',
#        'Combat Commander BP #5: Fall of the West, 2nd Printing',
#        'Combat Commander BP #4: New Guinea, 2nd Printing',
#        'Combat Commander BP #3: Normandy, 2nd Printing',
#        'Combat Commander BP #2: Stalingrad, 3rd Printing',
#        'Combat Commander BP #1: Paratroops, 3rd Printing',
#        'Comanchería: The Rise and Fall of the Comanche Empire, 2nd Printing',
#        'Comancheria Mounted Map', "Colonial: Europe's Empires Overseas",
#        'Colonial Twilight: The French-Algerian War, 1954-62',
#        'Colonial Twilight Mounted Map',
#        'Clash of Sovereigns: The War of the Austrian Succession, 1740-48',
#        'Clash of Monarchs', 'Clash of Giants: Civil War',
#        'Clash of Giants II', 'Clash of Giants', 'Churchill, 3rd Printing',
#        'Churchill Mounted Map', "China's War: 1937-1941",
#        'Chariots of Fire, 2nd Printing', 'Charioteer', 'Chandragupta',
#        'CDG Solo System', 'Cataphract, 2nd Printing',
#        'Cataclysm, 2nd Printing', 'Cataclysm Mounted Maps + 3" Box',
#        'Beneath the Med', 'Combat Commander: Europe, 5th Printing',
#        'Bear Trap: The Soviet-Afghan War, 1979-1989',
#        'Battles with the Gringos',
#        'Ancient Civilizations of the Inner Sea',
#        'American Revolution Tri-Pack',
#        'American Revolution Tri Pack Mounted Maps',
#        'All Bridges Burning: Red Revolt and White Guard in Finland, 1917-18',
#        'Alesia', 'Air Bridge to Victory', 'Absolute War',
#        'A World at War, 3rd Printing',
#        'A Time for Trumpets: The Battle of the Bulge, December 1944',
#        'A Distant Plain, 3rd Printing', 'A Distant Plain Mounted Map',
#        '4CMBG: MBT Expansion #3',
#        'Ancient Civilizations of the Middle East',
#        '2" Deep Heavy Duty White Game Box', '1989 Mounted Map',
#        '1960: The Making of the President, 2nd Printing',
#        '1960 Mounted Map', '1918/1919: Storm in the West',
#        '1914: Twilight in the East - Reprint Ed.',
#        "1914: Glory's End / When Eagles Fight",
#        '1914: Dispatches (Oregon ConSim Journal)',
#        '1914, Serbien muß sterbien', '1914, Offensive à outrance',
#        '1862: Railway Mania in the Eastern Counties', '1848: Australia',
#        'Manifest Destiny', '1989, 2nd Printing',
#        'Andean Abyss 2nd Ed. Update Kit', 'Andean Abyss Mounted Map',
#        'Andean Abyss, 2nd Printing', 'Battles of Waterloo',
#        'Battles of the Warrior Queen',
#        'Battles for the Shenandoah: A Death Valley Expansion',
#        'Battle of White Plains', 'Battle Line, Medieval-Themed Edition',
#        'Battle Line, 11th Printing', 'Battle for North Africa',
#        'Barbarossa: Kiev to Rostov',
#        'Barbarossa: Army Group Center, 1941, 2nd Edition',
#        'Barbarossa: Crimea',
#        'Barbarossa: Army Group South, 1941, 2nd Edition',
#        'Barbarossa: Army Group North, 1941, 2nd Edition',
#        'Barbarian (SPQR Module)', 'BAOR: MBT Expansion',
#        'Banish the Snakes', 'Banish All Their Fears', 'Attila',
#        'Atlantic Chase', 'At Any Cost: Metz 1870', 'Asia Engulfed',
#        'Arquebus: Men of Iron Volume IV',
#        'Ariovistus: A Falling Sky Expansion', "Ardennes '44, 3rd Edition",
#        "Ardennes '44 Mounted Maps", 'Arctic Storm', 'Apocalypse Road',
#        'Bayonets & Tomahawks',
#        'Combat Commander: Mediterranean, 3rd Printing',
#        '1846: The Race to the Midwest, 1846-1935, 2nd Printing',
#        'Gringo!', 'Combat Commander: Pacific, 2nd Printing',
#        'Great Battles of Alexander - Expanded Deluxe Ed, 2nd Printing',
#        'Grand Prix Track Set', 'Grand Prix - New Track Pack',
#        'Grand Prix', 'Grand Illusion',
#        "Golan '73: FAB #3 - Mounted Mapboard", "Golan '73: FAB #3",
#        'Glory III', 'Glory II: Across the Rappahannock (ziplock)',
#        'Glory', 'Germantown, 1777', 'Guilford', 'Gergovia', 'Genesis',
#        'Flashpoint: South China Sea', 'Fire in the Lake, 3rd Printing',
#        'Fire in the Lake Tru’ng Bot Update Pack',
#        'Fire in the Lake Mounted Map',
#        'Fire in the Lake 2nd Ed. Update Kit',
#        "Fighting Formations: Grossdeutschland Division's Battle for Kharkov",
#        'Fighting Formations: GD Infantry Div.',
#        'Fields of Fire: The Bulge Campaign',
#        'Fields of Fire, 2nd Edition',
#        'Fields of Fire Vol. II: "With The Old Breed"',
#        'Fields of Despair, 2nd Printing', 'Genesis - Mounted Mapboard',
#        'Fields of Despair Mounted Map',
#        'Gustav Adolf: With God & Victorious Arms',
#        'Here I Stand 500th Anniversary Reprint Edition', 'Lost Victory',
#        'Lion of the North',
#        'Liberty or Death: The American Insurrection, 3rd Printing',
#        'Liberty or Death Mounted Map', 'Leaping Lemmings Mounted Map',
#        'Leaping Lemmings', 'Labyrinth: The Awakening 2010-?',
#        'Labyrinth Mounted Map', 'Labyrinth 4th Printing', 'Kutuzov',
#        'Kasserine', 'Hellenes', 'June 6', 'Iron and Oak',
#        'Invasion: Sicily', 'Invasion: Norway',
#        'Into the Woods: The Battle of Shiloh', 'Infidel',
#        'Imperial Struggle', 'Illusions of Glory Mounted Map',
#        'Illusions of Glory', 'Hoplite, 2nd Printing',
#        "Holland '44: Operation Market-Garden", "Holland '44 Mounted Map",
#        "Hitler's Reich", 'Ivanhoe: The Age of Chivalry',
#        'Falling Sky: The Gallic Revolt Against Caesar, 2nd Printing',
#        'Flying Colors 3rd Edition Update Kit',
#        'Fall of Saigon: A Fire in the Lake Expansion',
#        'Cuba Libre, 4th Printing', 'Cuba Libre Mounted Map',
#        'Crusader: FAB #4', 'Crown of Roses', 'Crisis: Korea 1995',
#        'Counter Trays (10)', 'Corsairs & Hellcats',
#        'Conquest of Paradise - Mounted Mapboard',
#        'Conquest of Paradise - 2nd Ed.', 'Conquest and Consequence',
#        'Congress of Vienna', 'Falling Sky Mounted Map',
#        'Commands & Colors: Napoleonics, 4th Printing',
#        'Commands & Colors: Napoleonics Expansion 6: EPIC Napoleonics',
#        'Commands & Colors: Napoleonics Expansion 5: Generals, Marshals, Tacticians',
#        'Commands & Colors: Napoleonics Exp: The Spanish Army, 3rd Printing',
#        'Commands & Colors: Napoleonics Exp: The Russian Army, 4th Printing',
#        'Commands & Colors: Napoleonics Exp: The Prussian Army, 2nd Printing',
#        'Commands & Colors: Napoleonics Exp: The Austrian Army, 3rd Printing',
#        'Commands & Colors: Napoleonics Exp 7: La Grande Battles',
#        'Commands & Colors: Medieval, 2nd Printing',
#        'Commands & Colors: Ancients, 7th Printing',
#        'Commands & Colors Napoleonics Mounted Map',
#        'Commands & Colors Napoleonics Epics Mounted Maps',
#        'Commands & Colors Medieval Mounted Map',
#        'Combat Commander: Tournament Battle Pack',
#        'Combat Commander: Resistance, 2nd Printing',
#        'Cuius Regio: The Thirty Years War', 'Dark Valley Mounted Maps',
#        'Commands & Colors: Samurai Battles',
#        'Death Valley: Battles for the Shenandoah', 'Dead of Winter',
#        'Fading Glory Mounted Map', 'Expansion or Extinction',
#        'Europe Engulfed', 'Enemy Coast Ahead: The Doolittle Raid',
#        'Enemy Coast Ahead: The Dambuster Raid, 2nd Printing',
#        'Empire of the Sun, 4th Printing',
#        'Empire of the Sun Cards (2 decks - 2019 3rd Printing)',
#        'Empire of the Sun - Mounted Mapboard', 'Email Gift Certificate',
#        'Elusive Victory', 'Eighth Air Force', 'Eagle of Lille',
#        'Fading Glory: Napoleonic Series 20 Multi-Pack #1',
#        "Devil's Horsemen", "Dubno '41", 'Diadochoi', 'Dictator',
#        'Dominant Species 2011 Reprint Tile/Marker Sheets (7)',
#        'Dominant Species Mounted Map',
#        'Dominant Species Card Deck (3rd Printing)',
#        'Dominant Species: Marine, 2nd Printing',
#        'Dominant Species: The Card Game', 'Downfall Mounted Map + 3" Box',
#        'Downfall: Conquest of the Third Reich, 1942-1945', 'Downtown',
#        'Dominant Species, 6th Printing',
#        '1/2 Countersheet for 1914 Games', '18 India',
#        'Baltic Empires: The Northern Wars of 1558-1721',
#        'Away Team: The Voyages of the Pandora',
#        'Atlantic Chase, 2nd Printing', "Ardennes '44, 4th Printing",
#        "Ardennes '44 4th Printing Mounted Maps",
#        'American Revolution Tri-Pack #2',
#        'Almoravid: Reconquista and Riposte in Spain, 1085-1086',
#        'A Gest of Robin Hood',
#        'A Fading Star: Insurgency and Piracy in Somalia',
#        'A Distant Plain, 4th Printing',
#        '1960: The Making of the President, 3rd Printing', '18EUS',
#        '1848: The Springtime of Nations', '1833NE',
#        'American Revolution Tri-Pack, 2nd Printing',
#        "Ardennes '44, 4th Printing Mounted Maps",
#        'Andean Abyss, 3rd Printing', 'A World at War, 4th Printing',
#        'A World at War Mounted Maps', '3" Deep Heavy Duty White Game Box',
#        '2023 Replacement Countersheet',
#        '1914: Twilight in the East Reprint Edition', '1867 Big Wyoming',
#        '1862 Mounted Map', '18 India Mounted Map',
#        '1848: Australia Mounted Map'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# Prepare data
dates = df["Date"].dropna().sort_values().unique()
titles = df["Title"].unique()
date_indices = {date: idx for idx, date in enumerate(dates)}

# Example data for visualization (replace with your actual data logic)
cpu_1 = [(0, 3), (3.5, 1), (5, 5)]

# Interactive filter
def plot_filtered(title_filter):
     # Adjust height as needed

    # Filter logic: Only show data for the selected title
    if title_filter != "All":
        filtered_titles = [title_filter]
    else:
        filtered_titles = titles
        
    fig, ax = plt.subplots(figsize=(15, len(filtered_titles))) 

    # Plot data (replace with your actual logic for filtering data)
    for idx, title in enumerate(filtered_titles):
        # Filter rows for the current title
        title_data = df[df["Title"] == title]
        
        # Example: Create a broken_barh plot for the title's data
        # Replace this logic with your actual plotting logic
        
        for date_idx, date in enumerate(dates):
            item = title_data[title_data["Date"] == date]
            if not item.empty:
                if item["IsP500"].values[0]:
                    ax.plot(date_idx, idx, 'o', color='orange')
                elif item["IsOutOfStock"].values[0]:
                     ax.plot(date_idx, idx, 'o', color='red')
                else:
                    ax.plot(date_idx, idx, 'o', color='green')
            
        
    
    
    # ax.broken_barh(cpu_1, (-0.2, 0.4))

    # Set x-axis to use sequential indices for dates
    ax.set_xlim(-0.5, len(dates) - 0.5)
    ax.set_xticks(range(len(dates)))
    ax.set_xticklabels(dates, rotation=45, ha="right")

    # Set y-axis to use Titles
    ax.set_yticks(range(len(filtered_titles)), labels=filtered_titles)
    ax.invert_yaxis()
    ax.set_title("Resource Usage")

    plt.show()

# Create a dropdown widget for filtering titles
title_dropdown = widgets.Dropdown(
    options=["All"] + list(titles), 
    value='All',
    description="Title:",
    style={"description_width": "initial"},
)

# Link the dropdown to the plot function
interactive_plot = widgets.interactive(plot_filtered, title_filter=title_dropdown)
display(interactive_plot)

# plot_filtered("All")
# Out:
# interactive(children=(Dropdown(description='Title:', options=('All', '1805: Sea of Glory', 'Risorgimento 1859'…
